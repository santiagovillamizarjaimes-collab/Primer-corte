# %% [markdown]
# <a href="https://colab.research.google.com/github/santiagovillamizarjaimes-collab/Primer-corte/blob/main/clasedetaller.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nombre: Erick santiago villamizar Jaimes \
# Parte II\
# Instrucción 1:

# %%
A = (1, 2, 3, 4)
B = (4, 5, 5, 6)

# %%
4 in A
# Out:
# False

# %%
5 in A
# Out:
# False

# %%
6 in A
# Out:
# False

# %% [markdown]
# La sentencia in se utiliza para determinar si un elemento pertenece a una tupla o no. El elemento de salida al utilizar la sentencia in es de tipo booleano.

# %%
B.count(5)
# Out:
# 2

# %% [markdown]
# El método .count() aplicado en una tupla cuenta cuantas veces aparece la componente

# %%
B.count(7)
# Out:
# 0

# %% [markdown]
# Si un elemento no está en mi tupla, el método count devuelve 0.

# %% [markdown]
# Instrucción 2
#
# En el previo hay 4 instrucciones

# %%
datos2  = {"a": 1, "b": 2, "c": 3, "d": 4}

# %%
datos2.pop("d")
datos2
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %% [markdown]
# El método por si mismo no tiene salida. Para mostrar qué hace el método explícitamente se debe mostrar una vez se ejecuta.

# %% [markdown]
# El método pop aplicado a un diccionario evaluado en una clave elimina dicha clave junto con su valor.

# %%
datos2.pop("e")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_7787/843352533.py in <cell line: 0>()
# ----> 1 datos2.pop("e")
#
# KeyError: 'e'

# %% [markdown]
# Al evaluar el método pop en una clave no existente se tiene como salida un error.

# %% [markdown]
# Instrucción 3

# %%
datos3 = {1: "a", 2: "b", 3:"c", 4: "d"}

# %%
datos3.items()
# Out:
# dict_items([(1, 'a'), (2, 'b'), (3, 'c'), (4, 'd')])

# %%
for i in datos3.items():
  print(i)
# Out:
# (1, 'a')
# (2, 'b')
# (3, 'c')
# (4, 'd')

# %% [markdown]
# La salida al aplicar el método ítems en un diccionario corresponde a las tuplas (clave, valor) generadas a partir del diccionario

# %%
type(datos3.items())
# Out:
# dict_items

# %% [markdown]
# El tipo de objeto que tiene la salida al aplicar el método ítems en un diccionario es de tipo dict_items

# %%
a = datos3.items()
a
# Out:
# dict_items([(1, 'a'), (2, 'b'), (3, 'c'), (4, 'd')])

# %% [markdown]
# Explicítamente en un objeto se transforman todas las componentes clave-valor de un diccionario en tuplas

# %%
m= 6
for n in range(0, m+1):
  if n % 2 == 0:
    print(n, "es par y su doble es", n * 2)
  else:
    print(n, "es impar y su triple es", n * 3)

# %%
def reconocerparimpar(m):
  while m.is_integer():
    if m % 2 ==

# %% [markdown]
# Código 2

# %%
def contador_vocales1(palabra):
  letras = "abcdefghijklmnñopqrstuvwxyz"
  letras1 = letras.upper()
  numeros = "0123456789"
  espacio = ""

  contador = 0
  contador1 = 0
  contador2 = 0
  contador3 = 0
  contador4 = 0

  for letra in palabra:
    if letra in letras:
      contador += 1
    elif letra in letras1:
      contador1 += 1
    elif letra in numeros:
      contador2 += 1
    elif letra in espacio:
      contador3 += 1
    else:
      contador4 += 1
  return({"Cantidad de letras minusculas: " contador,
          "Cantidad de letras mayusculas: " contador1,
          })

# %% [markdown]
# Código 3:
